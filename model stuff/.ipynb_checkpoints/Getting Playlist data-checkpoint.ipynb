# %% [markdown]
# # Scrapping the Spotify Dataset

# %% [markdown]
# ### Tutorials:
# * Access and get spotify data:  https://towardsdatascience.com/extracting-song-data-from-the-spotify-api-using-python-b1e79388d50
# * Build a recommendation system from the Spotify API based on CF: https://towardsdatascience.com/part-iii-building-a-song-recommendation-system-with-spotify-cf76b52705e7
# * Spotipy library: #
# https://spotipy.readthedocs.io/en/master/

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
cid="715ae75406e24c24a3641929260ca343"
secret="e60a686258c646b7a4d3f9636b3235db"

# %%
#Authentication - without user
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
#Extract the track data
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f"
playlist_URI = playlist_link.split("/")[-1].split("?")[0]
track_uris = [x["track"]["uri"] for x in sp.playlist_tracks(playlist_URI)["items"]]

# %%
#Info from each track
for track in sp.playlist_tracks(playlist_URI)["items"]:
    #URI
    track_uri = track["track"]["uri"]
    
    #Track name
    track_name = track["track"]["name"]
    
    #Main Artist
    artist_uri = track["track"]["artists"][0]["uri"]
    artist_info = sp.artist(artist_uri)
    
    #Name, popularity, genre
    artist_name = track["track"]["artists"][0]["name"]
    artist_pop = artist_info["popularity"]
    artist_genres = artist_info["genres"]
    
    #Album
    album = track["track"]["album"]["name"]
    
    #Popularity of the track
    track_pop = track["track"]["popularity"]

# %%
sp.audio_features(track_uri)[0]
# Out:
# {'danceability': 0.519,
#  'energy': 0.595,
#  'key': 2,
#  'loudness': -5.001,
#  'mode': 1,
#  'speechiness': 0.0283,
#  'acousticness': 0.00151,
#  'instrumentalness': 0,
#  'liveness': 0.0762,
#  'valence': 0.237,
#  'tempo': 129.786,
#  'type': 'audio_features',
#  'id': '1Ame8XTX6QHY0l0ahqUhgv',
#  'uri': 'spotify:track:1Ame8XTX6QHY0l0ahqUhgv',
#  'track_href': 'https://api.spotify.com/v1/tracks/1Ame8XTX6QHY0l0ahqUhgv',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Ame8XTX6QHY0l0ahqUhgv',
#  'duration_ms': 247067,
#  'time_signature': 4}

# %%
# How to create playlist from list of songs

# %%
# IDEA recommend an artist from book

# %%
#Get all playlists from spotify
user="https://open.spotify.com/user/spotify?si=0759e31631a54969"

# %%
#Search for playlists with a name
import sys
import pprint

playlist_name = 'charlie and the chocolate factory'
result = sp.search(playlist_name,limit=50, offset=0, type='playlist')
pprint.pprint(result)
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?query=charlie+and+the+chocolate+factory&type=playlist&offset=0&limit=50',
#                'items': [{'collaborative': False,
#                           'description': '',
#                           'external_urls': {'spotify': 'https://open.spotify.com/playlist/5T1b4G3al1oOBJYLCwNYMO'},
#                           'href': 'https://api.spotify.com/v1/playlists/5T1b4G3al1oOBJYLCwNYMO',
#                           'id': '5T1b4G3al1oOBJYLCwNYMO',
#                           'images': [{'height': 640,
#                                       'url': 'https://i.scdn.co/image/ab67616d0000b2733174f44792dded2b1ace8c3d',
#                                       'width': 640}],
#                           'name': 'Charlie and the Chocolate Factory: The New '
#                                   'Musical',
#                           'owner': {'display_name': 'octafiore',
# ...
